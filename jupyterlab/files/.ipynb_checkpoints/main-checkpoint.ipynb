# %% [markdown]
# ## Импортируем модули

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Открываем базу

# %%
cnx = sqlite3.connect(r'../db/my_database_last.db')

# %% [markdown]
# ## Получаем данные из таблицы. Создаем dataframe.

# %%
fields_list = ["district", "rating_all", "rating_house", "rating_flat", "record_status"]
fields = ', '.join(fields_list)
where = f"record_status = 2"
sql = f"SELECT {fields} FROM avito WHERE {where}"
df = pd.read_sql_query(sql, cnx)

# %%
df.head()
# Out:
#       district  rating_all  rating_house  rating_flat record_status
# 0     Бежицкий       13.85          4.15            5             2
# 1     Бежицкий        8.60          3.36            3             2
# 2    Фокинский        7.31          3.51            3             2
# 3  Володарский       13.56          3.67            5             2
# 4    Советский       11.40          2.53            5             2

# %%
df.isna().sum()
# Out:
# district         0
# rating_all       0
# rating_house     0
# rating_flat      0
# record_status    0
# dtype: int64

# %%
df.describe()
# Out:
#        rating_all  rating_house  rating_flat
# count    34.00000     34.000000    34.000000
# mean     10.12500      3.746471     4.029412
# std       2.32586      0.736202     1.313918
# min       1.25000      1.250000     0.000000
# 25%       9.20750      3.380000     3.250000
# 50%      10.30500      3.720000     4.000000
# 75%      11.44250      4.380000     5.000000
# max      13.85000      4.690000     6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   district       34 non-null     object
#  1   rating_all     34 non-null     float64
#  2   rating_house   34 non-null     float64
#  3   rating_flat    34 non-null     int64
#  4   record_status  34 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.5+ KB

# %% [markdown]
# ## matplotlib - построение histogram

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
ax1.hist(df["rating_all"])
ax1.title.set_text('Суммарный рейтинг')
ax1.set_xlabel('Рейтинг')
ax1.set_ylabel('Кол-во')

ax2.hist(df["rating_house"])
ax2.title.set_text('Рейтинг дома')
ax2.set_xlabel('Рейтинг')
ax2.set_ylabel('Кол-во')

ax3.hist(df["rating_flat"])
ax3.title.set_text('Рейтинг квартиры')
ax3.set_xlabel('Рейтинг')
ax3.set_ylabel('Кол-во')

plt.tight_layout()
# fig.suptitle("Графики распределения рейтингов")
fig.show()

# %% [markdown]
# ## seaborn - построение histogram

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))

# Plot on the first subplot
sns.histplot(data=df["rating_all"], ax=ax1)
ax1.title.set_text('Суммарный рейтинг')
ax1.set_xlabel('Рейтинг')
ax1.set_ylabel('Кол-во')

# Plot on the second subplot
sns.histplot(data=df["rating_house"], ax=ax2)
ax2.title.set_text('Рейтинг дома')
ax2.set_xlabel('Рейтинг')
ax2.set_ylabel('Кол-во')

# Plot on the third subplot
sns.histplot(data=df["rating_flat"], ax=ax3)
ax3.title.set_text('Рейтинг квартиры')
ax3.set_xlabel('Рейтинг')
ax3.set_ylabel('Кол-во')

# Adjust the spacing between plots
plt.tight_layout()

# Display the plot
plt.show()
